# %% [markdown]
# # Research Question
# Can machine learning models predict the financial risk of Turkish publicly traded companies using financial ratios?

# %%
import pandas as pd

# %%
df = pd.read_csv("financial_data.csv")

# %%
df.columns
# Out:
# Index(['Şirket Adı', 'Şirketin Kodu', 'Periyot', 'Yıl', 'Dönen Varlıklar',
#        'Duran Varlıklar', 'Toplam Varlıklar', 'Kısa Vadeli Yükümlülükler',
#        'Uzun Vadeli Yükümlülükler', 'Toplam Yükümlülükler',
#        'Toplam Özkaynaklar', 'Ana Ortaklığa Ait Özkaynaklar',
#        'Kontrol Gücü Olmayan Kaynaklar', 'Toplam Kaynaklar', 'Cari Oran',
#        'Dönen Varlıklar / Aktif (%)', 'Asit Test Oranı', 'Nakit Oranı',
#        'Aktif Karlılık (%)', 'Faaliyet Kar Marjı', 'Esas Faaliyet Kar Marjı',
#        'Brüt Kar Marjı (%)', 'FAVÖK Marjı (%)', 'Net Kar Marjı',
#        'Özsermaye Karlılığı (%)', 'VAFÖK Marjı', 'ROCE Oranı',
#        'Finansman Gider / Net Satış', 'Borç Kaynak Oranı',
#        'Duran Varlıklar / Aktif ', 'Duran Varlıklar / Maddi Özkaynak',
#        'Esas Faaliyet Karı / Kısa Vadeli Borç', 'FAVÖK / Kısa Vade Borç',
#        'Net Borç / FAVÖK', 'Kısa Vade Borç / Aktif',
#        'Kısa Vade Borç / Dönen Varlık', 'Kısa Vade Borç / Özsermaye',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27298 entries, 0 to 27297
# Data columns (total 53 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Şirket Adı                             27298 non-null  object
#  1   Şirketin Kodu                          27298 non-null  object
#  2   Periyot                                27298 non-null  object
#  3   Yıl                                    27298 non-null  int64
#  4   Dönen Varlıklar                        27298 non-null  float64
#  5   Duran Varlıklar                        27298 non-null  float64
#  6   Toplam Varlıklar                       27298 non-null  float64
#  7   Kısa Vadeli Yükümlülükler              27298 non-null  float64
#  8   Uzun Vadeli Yükümlülükler              27298 non-null  float64
#  9   Toplam Yükümlülükler                   27298 non-null  float64
# ...

# %%
df["Görüs Tipi"].unique()
# Out:
# array(['Şartlı', nan, 'Olumlu', 'Görüş bildirmekten kaçınma', 'Olumsuz'],
#       dtype=object)

# %%
df.head()
# Out:
#                                 Şirket Adı Şirketin Kodu  Periyot   Yıl  \
# 0  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP   Yıllık  2020
# 1  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP  9 Aylık  2020
# 2  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP  6 Aylık  2020
# 3  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP  6 Aylık  2020
# 4  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP  3 Aylık  2020
#
#    Dönen Varlıklar  Duran Varlıklar  Toplam Varlıklar  \
# 0      452463975.0       15063837.0       467527812.0
# 1              0.0              0.0               0.0
# 2              0.0              0.0               0.0
# 3              0.0              0.0               0.0
# 4              0.0              0.0               0.0
#
#    Kısa Vadeli Yükümlülükler  Uzun Vadeli Yükümlülükler  Toplam Yükümlülükler  \
# 0                325928352.0                  2806817.0           328735169.0
# ...

# %%
#target -> Görüs Tipi

# %%
df["Görüs Tipi"].value_counts(dropna=False)
# Out:
# Görüs Tipi
# NaN                           16547
# Olumlu                         9610
# Şartlı                         1054
# Görüş bildirmekten kaçınma       81
# Olumsuz                           6
# Name: count, dtype: int64

# %%
df = df.dropna(subset=["Görüs Tipi"])

# %%
df["Görüs Tipi"].value_counts(dropna=False)
# Out:
# Görüs Tipi
# Olumlu                        9610
# Şartlı                        1054
# Görüş bildirmekten kaçınma      81
# Olumsuz                          6
# Name: count, dtype: int64

# %% [markdown]
# # Values
# Olumlu → 0 (Healthy)
#
# Şartlı → 1 (Risk)
#
# Olumsuz → 1 (Risk)
#
# Görüş bildirmekten kaçınma → 1 (Risk)

# %%
df["risk"] = df["Görüs Tipi"].map({
    "Olumlu":0,
    "Şartlı":1,
    "Olumsuz":1,
    "Görüş bildirmekten kaçınma":1
})
# Out:
# C:\Users\bilal\AppData\Local\Temp\ipykernel_33000\3061077481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["risk"] = df["Görüs Tipi"].map({

# %%
df["risk"].value_counts()
# Out:
# risk
# 0    9610
# 1    1141
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                 Şirket Adı Şirketin Kodu  Periyot   Yıl  \
# 0  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP   Yıllık  2020
# 2  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP  6 Aylık  2020
# 3  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP  6 Aylık  2020
# 5  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP   Yıllık  2021
# 7  A1 CAPİTAL YATIRIM MENKUL DEĞERLER A.Ş.         A1CAP  6 Aylık  2021
#
#    Dönen Varlıklar  Duran Varlıklar  Toplam Varlıklar  \
# 0      452463975.0       15063837.0       467527812.0
# 2              0.0              0.0               0.0
# 3              0.0              0.0               0.0
# 5      851508753.0       42045725.0       893554478.0
# 7      557284135.0       37823261.0       595107396.0
#
#    Kısa Vadeli Yükümlülükler  Uzun Vadeli Yükümlülükler  Toplam Yükümlülükler  \
# 0                325928352.0                  2806817.0           328735169.0
# ...

# %%
y=df["risk"]
X = df.drop(columns=["Görüs Tipi","risk"])

# %%
y.value_counts()
# Out:
# risk
# 0    9610
# 1    1141
# Name: count, dtype: int64
